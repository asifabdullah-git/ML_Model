# %%
import pandas as pd
import numpy as np
import csv
#import matplotlib.pyplot as plt
#matplotlib inline
#import seaborn as sns

# %%
data = pd.read_csv("har.csv")
data.head()
#data.shape
# Out:
#    location         X         Y         Z  label
# 0         1  0.060410 -0.382996 -0.925644     14
# 1         1  0.047729 -0.405075 -0.921341     14
# 2         1  0.063873 -0.401993 -0.922760     14
# 3         1  0.021912 -0.461716 -0.915222     14
# 4         1  0.022583 -0.421509 -1.008743     14

# %%
l_11 = data[data.label==11]
l_12 = data[data.label==12]
l_13 = data[data.label==13]
l_14 = data[data.label==14]
l_15 = data[data.label==15]


l_21 = data[data.label==21]
l_22 = data[data.label==22]
l_23 = data[data.label==23]

l_31 = data[data.label==31]
l_32 = data[data.label==32]
l_33 = data[data.label==33]

# %%
l_11.to_csv("E:\Fall19\cse475\pp\label_csv\label_11.csv")
l_12.to_csv("E:\Fall19\cse475\pp\label_csv\label_12.csv")
l_13.to_csv("E:\Fall19\cse475\pp\label_csv\label_13.csv")
l_14.to_csv("E:\Fall19\cse475\pp\label_csv\label_14.csv")
l_15.to_csv("E:\Fall19\cse475\pp\label_csv\label_15.csv")


l_21.to_csv("E:\Fall19\cse475\pp\label_csv\label_21.csv")
l_22.to_csv("E:\Fall19\cse475\pp\label_csv\label_22.csv")
l_23.to_csv("E:\Fall19\cse475\pp\label_csv\label_23.csv")

l_31.to_csv("E:\Fall19\cse475\pp\label_csv\label_31.csv")
l_32.to_csv("E:\Fall19\cse475\pp\label_csv\label_32.csv")
l_33.to_csv("E:\Fall19\cse475\pp\label_csv\label_33.csv")

# %%
l_11_mean = l_11.groupby(np.arange(len(l_11))//100).mean()
l_11_mean = l_11_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_11_std = l_11.groupby(np.arange(len(l_11))//100).std()
l_11_std = l_11_std[['X','Y','Z']]
l_11_std = l_11_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_11_skew = l_11.groupby(np.arange(len(l_11))//100).skew()
l_11_skew = l_11_skew[['X','Y','Z']]
l_11_skew = l_11_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_11 = pd.concat([l_11_mean, l_11_std, l_11_skew], axis=1)
result_11 = result_11[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_11.to_csv("E:/Fall19/cse475/pp/result_csv/result_11.csv")


l_12_mean = l_12.groupby(np.arange(len(l_12))//100).mean()
l_12_mean = l_12_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_12_std = l_12.groupby(np.arange(len(l_12))//100).std()
l_12_std = l_12_std[['X','Y','Z']]
l_12_std = l_12_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_12_skew = l_12.groupby(np.arange(len(l_12))//100).skew()
l_12_skew = l_12_skew[['X','Y','Z']]
l_12_skew = l_12_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_12 = pd.concat([l_12_mean, l_12_std, l_12_skew], axis=1)
result_12 = result_12[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_12.to_csv("E:/Fall19/cse475/pp/result_csv/result_12.csv")


l_13_mean = l_13.groupby(np.arange(len(l_13))//100).mean()
l_13_mean = l_13_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_13_std = l_13.groupby(np.arange(len(l_13))//100).std()
l_13_std = l_13_std[['X','Y','Z']]
l_13_std = l_13_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_13_skew = l_13.groupby(np.arange(len(l_13))//100).skew()
l_13_skew = l_13_skew[['X','Y','Z']]
l_13_skew = l_13_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_13 = pd.concat([l_13_mean, l_13_std, l_13_skew], axis=1)
result_13 = result_13[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_13.to_csv("E:/Fall19/cse475/pp/result_csv/result_13.csv")


l_14_mean = l_14.groupby(np.arange(len(l_14))//100).mean()
l_14_mean = l_14_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_14_std = l_14.groupby(np.arange(len(l_14))//100).std()
l_14_std = l_14_std[['X','Y','Z']]
l_14_std = l_14_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_14_skew = l_14.groupby(np.arange(len(l_14))//100).skew()
l_14_skew = l_14_skew[['X','Y','Z']]
l_14_skew = l_14_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_14 = pd.concat([l_14_mean, l_14_std, l_14_skew], axis=1)
result_14 = result_14[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_14.to_csv("E:/Fall19/cse475/pp/result_csv/result_14.csv")


l_15_mean = l_15.groupby(np.arange(len(l_15))//100).mean()
l_15_mean = l_15_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_15_std = l_15.groupby(np.arange(len(l_15))//100).std()
l_15_std = l_15_std[['X','Y','Z']]
l_15_std = l_15_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_15_skew = l_15.groupby(np.arange(len(l_15))//100).skew()
l_15_skew = l_15_skew[['X','Y','Z']]
l_15_skew = l_15_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_15 = pd.concat([l_15_mean, l_15_std, l_15_skew], axis=1)
result_15 = result_15[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_15.to_csv("E:/Fall19/cse475/pp/result_csv/result_15.csv")

# %%
l_21_mean = l_21.groupby(np.arange(len(l_21))//100).mean()
l_21_mean = l_21_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_21_std = l_21.groupby(np.arange(len(l_21))//100).std()
l_21_std = l_21_std[['X','Y','Z']]
l_21_std = l_21_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_21_skew = l_21.groupby(np.arange(len(l_21))//100).skew()
l_21_skew = l_21_skew[['X','Y','Z']]
l_21_skew = l_21_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_21 = pd.concat([l_21_mean, l_21_std, l_21_skew], axis=1)
result_21 = result_21[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_21.to_csv("E:/Fall19/cse475/pp/result_csv/result_21.csv")


l_22_mean = l_22.groupby(np.arange(len(l_22))//100).mean()
l_22_mean = l_22_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_22_std = l_22.groupby(np.arange(len(l_22))//100).std()
l_22_std = l_22_std[['X','Y','Z']]
l_22_std = l_22_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_22_skew = l_22.groupby(np.arange(len(l_22))//100).skew()
l_22_skew = l_22_skew[['X','Y','Z']]
l_22_skew = l_22_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_22 = pd.concat([l_22_mean, l_22_std, l_22_skew], axis=1)
result_22 = result_22[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_22.to_csv("E:/Fall19/cse475/pp/result_csv/result_22.csv")


l_23_mean = l_23.groupby(np.arange(len(l_23))//100).mean()
l_23_mean = l_23_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_23_std = l_23.groupby(np.arange(len(l_23))//100).std()
l_23_std = l_23_std[['X','Y','Z']]
l_23_std = l_23_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_23_skew = l_23.groupby(np.arange(len(l_23))//100).skew()
l_23_skew = l_23_skew[['X','Y','Z']]
l_23_skew = l_23_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_23 = pd.concat([l_23_mean, l_23_std, l_23_skew], axis=1)
result_23 = result_23[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_23.to_csv("E:/Fall19/cse475/pp/result_csv/result_23.csv")

# %%
l_31_mean = l_31.groupby(np.arange(len(l_31))//100).mean()
l_31_mean = l_31_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_31_std = l_31.groupby(np.arange(len(l_31))//100).std()
l_31_std = l_31_std[['X','Y','Z']]
l_31_std = l_31_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_31_skew = l_31.groupby(np.arange(len(l_31))//100).skew()
l_31_skew = l_31_skew[['X','Y','Z']]
l_31_skew = l_31_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_31 = pd.concat([l_31_mean, l_31_std, l_31_skew], axis=1)
result_31 = result_31[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_31.to_csv("E:/Fall19/cse475/pp/result_csv/result_31.csv")


l_32_mean = l_32.groupby(np.arange(len(l_32))//100).mean()
l_32_mean = l_32_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_32_std = l_32.groupby(np.arange(len(l_32))//100).std()
l_32_std = l_32_std[['X','Y','Z']]
l_32_std = l_32_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_32_skew = l_32.groupby(np.arange(len(l_32))//100).skew()
l_32_skew = l_32_skew[['X','Y','Z']]
l_32_skew = l_32_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_32 = pd.concat([l_32_mean, l_32_std, l_32_skew], axis=1)
result_32 = result_32[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_32.to_csv("E:/Fall19/cse475/pp/result_csv/result_32.csv")


l_33_mean = l_33.groupby(np.arange(len(l_33))//100).mean()
l_33_mean = l_33_mean.rename(columns={'X':'mean_X', 'Y' : 'mean_Y', 'Z' : 'mean_Z'})
l_33_std = l_33.groupby(np.arange(len(l_33))//100).std()
l_33_std = l_33_std[['X','Y','Z']]
l_33_std = l_33_std.rename(columns={'X':'std_X', 'Y' : 'std_Y', 'Z' : 'std_Z'})
l_33_skew = l_33.groupby(np.arange(len(l_33))//100).skew()
l_33_skew = l_33_skew[['X','Y','Z']]
l_33_skew = l_33_skew.rename(columns={'X':'skew_X', 'Y' : 'skew_Y', 'Z' : 'skew_Z'})
result_33 = pd.concat([l_33_mean, l_33_std, l_33_skew], axis=1)
result_33 = result_33[['location','mean_X','mean_Y','mean_Z','std_X','std_Y','std_Z','skew_X','skew_Y','skew_Z','label']]
result_33.to_csv("E:/Fall19/cse475/pp/result_csv/result_33.csv")

# %%
#result_33 = pd.concat([l_33_mean, l_33_std], axis=1)
result = result_11.append([result_12,result_13,result_14,result_15,result_21,
                           result_22,result_23,result_31,result_32,result_33])

#result = result.drop(result.columns[0], axis=1)
#result = result.drop(['Unnamed:0.1'])
#result =result.drop(columns=['Unnamend: 0.1'])
#result
result.to_csv("E:/Fall19/cse475/pp/final_filter.csv")
